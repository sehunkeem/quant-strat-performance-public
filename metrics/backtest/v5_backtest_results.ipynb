# %%
from backtester import run
from config import nb_args
from perf_utils import *

ASSET_TYPE = "crypto"
ANN_FACTOR = {"crypto": 365, "equities": 252}.get(ASSET_TYPE)

if ANN_FACTOR is None:
    raise ValueError(f"Unknown ASSET_TYPE: {ASSET_TYPE}")

# %%
df_results, df_weights = run(*nb_args)

# %%
perf_metrics(df_results, ANN_FACTOR)
# Out:
#                              Value
# Annual Arithmetic Return  0.349094
# CAGR                      0.402010
# Cumulative Return         1.237641
# Annual Volatility         0.148704
# Max Drawdown             -0.157139
# Average Drawdown         -0.035556
# Sharpe Ratio              2.347571
# Sortino Ratio             3.699969
# Calmar Ratio              2.221568
# Omega Ratio               1.382078
# Return Skewness           0.071525
# Return Kurtosis           1.337497
# VaR 5%                   -0.011334
# VaR 1%                   -0.018875
# Top 5%                    0.013117
# Top 1%                    0.021459
# Stability                 0.911306

# %%
plot_cumret(df_results, ANN_FACTOR)
plot_drawdown(df_results)
plot_monthly_returns_heatmap(df_results)
plot_rolling_sharpe(df_results, window=90, ann_factor=ANN_FACTOR)
